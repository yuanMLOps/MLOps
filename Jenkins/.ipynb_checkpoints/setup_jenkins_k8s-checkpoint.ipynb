# %% [markdown]
# ### set up Jenkins in K8s
#
# #### Install jenkins by helm
# ```bash
#  # create new namespace
#  kubectl create namespace jenkins
#
#  # download default values.yaml file from jenkins helm chart
#  helm show values jenkins/jenkins > jenkins_values.yaml
#
#   # you can edit and change settings in values.yaml and then update jenkins installation
#  helm install jenkins jenkins/jenkins -n jenkins -f jenkins_values.yaml
#
#  # or directly deploy jenkins with default values to jenkins namespace and then update
#  helm install jenkins jenkins/jenkins -n jenkins
#  helm upgrade jenkins jenkins/jenkins -f jenkins_values.yaml -n jenkins
#
#  # list all installed helm release
#  helm list -- all-namespaces
#
#  # show the status of an installed release with release name
#  # use this to get the random jenkins password generated by installation
#  helm status jenkins -n jenkins
#  ```
#
# #### uninstall jenkins by helm
# ```bash
# helm uninstall jenkins -n jenkins
#
# # remove pvc associated with jenkins
# kubectl delete pvc jenkins -n jenkins
# ```

# %% [markdown]
# #### Set up ingress
# * identify the ingress controller you want to use
# * refer to jenkins_ingress.yaml file for ingress
# * run `kubectl apply -f jenkins_ingress.yaml`
# * access jenkins

# %% [markdown]
# #### Set up credentials and host key to connect to github and bitbucket
# * generate host keys for GitHub and bitbucket
#     ```bash
#     # Example of github and bitbucket
#     ssh-keyscan github.com >> known_hosts
#     ssh-keyscan bitbucket.org >> known_hosts
#     ```
# * add host key to Jenkins
#   + Open Jenkins UI
#   + Log in to your Jenkins instance
#   + Go to Manage Jenkins (usually in the left sidebar)
#     + click Security
#     + find and click Git Host Key Verification Configuration
#
# * in Configure Host Key Verification
#   + Select "Manually provided keys" as the strategy
#   + In the Approved Host Keys section, paste the line you copied from ssh-keyscan, click Save
#     + You might see output in known_hosts like:
#     ```text
#     bitbucket.org:22 SSH-2.0-OpenSSH_8.2p1 Ubuntu-4ubuntu0.5
#     bitbucket.org ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIE...
#     ```
#     Only copy this line: `bitbucket.org ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIE...`
# * Generate SSH key of bitbucket/github for jenkins
#   + `ssh-keygen -t ed25519` and when prompt the file to save key, use /home/<your_home_folder>/.ssh/id\_ed25519
#   + the public and private key files are id\_ed25519.pub and id\_ed25519, respectively
# * Add public key to bitbucket
#   + copy public key file's content by `cat /home/<your_home_folder>/.ssh/id_ed25519.pub`
#   + go to bitbucket -> settings -> add SSH key -> add workspace key and paste the public key
# * Add private key from jenkins GUI
#   + in jenkins GUI -> manage Jenkins -> Credentials -> add SSH Username with private key
#     + input 'git' in Username
#     + in Private Key -> Enter directly, copy and paste the entire content of id\_ed25519 include ---begin and --end lines
# * test using a pipeline and build it
#   ```groovy
#   pipeline {
#       agent any
#
#       stages {
#           stage('Checkout') {
#               steps {
#                   git credentialsId: 'bitbucket_ssh',
#                   url: 'git@bitbucket.org:<org>/<repo name>.git',
#                   branch: 'main'
#               }
#           }
#
#           stage('Verify') {
#               steps {
#                   sh 'ls -la'
#               }
#           }
#       }
#   }
#   ```

# %% [markdown]
# #### Set up pipeline from jenkins GUI using kubernetes agent
# * define pipeline script from jenkins GUI
# * Using jenkinsfile is preferred compared to define pipelines in jenkins GUI
# * check if need to restrict to websocket and disable classic JNLP/TCP with port 50000 or via/tcpSlaveAgentListener
# * jenkins in k8s doesn't have agent: {docker {image: 'python:3.10'}} option. Only has any, kubernetes
# * jenkins in k8s don't config worker nodes, and therefore, no label nodes, which is used in typical jenkins config
#   + in typical jenkins
#     + make sure the worker node has installed a virtual env with all packages
#     + define worker node in agent { label 'worker node name'}
#     + you define worker node name and config in jenkins (see set up local jenkins link)
# ```groovy
# pipeline {
#   agent {
#     kubernetes {
#       defaultContainer 'python'  // set python as default container.
#       // must use command: -cat and tty:true to make container alive for jenkins to login to python container
#         yaml """
#     apiVersion: v1
#     kind: pod
#     spec:
#       containers:
#         - name: python
#           image: python:3.10
#           command:
#             - cat
#           tty: true
#     """
#     }
#     }
#
#     environment {
#         VENV_DIR = 'venv'
#     }
#
#     stages {
#       stage('Run') {
#         steps {
#           sh 'python --version'
#         }
#       }
#
#       stage('Git Checkout') {
#         steps {
#           git credentialsId: 'bitbucket_ssh',
#               url: 'git@github.com:yuanMLOps/LLM_NLP.git',
#               branch: 'main'
#         }
#       }
#
#       stage('Verify') {
#         steps {
#           sh 'ls-la'
#         }
#       }
#
#       stage('Setup python Environment') {
#         steps { // use . $VENV_DIR/bin/activate as source $VENV_DIR/bin/activate
#           sh '''
#           python3 -m venv $VENV_DIR
#           . $VENV_DIR/bin/activate
#
#           pip install -r requirements.txt
#           '''
#         }
#       }
#
#       stage('Run Tests') {
#         steps {
#           sh '''
#           . venv/bin/activate
#           which pytest
#           export PYTHONPATH=$(pwd)
#           pytest
#           '''
#         }
#       }
#
#     }
#   }
#  ```
#
# * refer the following link for jenkins project configuration
# ![image.png](attachment:308ea576-fecb-42e6-b431-a23c40a6f6b5.png)
# ![image.png](attachment:1bd09e0d-4ba5-490d-8b51-994fb2c3a410.png)

# %% [markdown]
# #### Set up pipeline by jenkinsfile in code repo using kubernetes agent
# * for step by step instruction to set up jenkinsfile pipeline, [refer to this link](Jenkinsfile_Setup_Guide.txt)
# * use websocket agent 8080 and disable classic JNLP/TCP with port 50000 or via/tcpSlaveAgentListener
#   + enable WebSocket agents in k8s from Jenkins UI
#     + Manage Jenkins -> Clouds -> Kubernetes -> Configure
#     + Check the box 'WebSocket' to use websocket
#     + make sure Jenkins URL is http://jenkins.jenkins.svc.cluster.local:8080
#     + make sure to leave jenkins tunnel as empty. DO NOT SET jenkins.jenkins.svc.cluster.local:50000
# * define jenkinsfile in the root folder of code repo
#   + don't need to include checkout stage in jenkinsfile since it will automatically check out the code
#   + other parts are the same as pipeline script defined in jenkins GUI
#   + you can't run jenkinsfile with docker as agent in typical/local jenkins since you can't specify which docker container to run pipeline reliably
#   + remember to select "pipeline script from SCM". see the attached screen shot.
# ```groovy
# pipeline {
#   agent {
#     kubernetes {
#       defaultContainer 'python'  // set python as default container.
#       // must use command: - cat and tty:true to make container alive for jenkins to login to python container
#       // we can also use - sleep infinity for the same purpose
#         yaml """
#     apiVersion: v1
#     kind: pod
#     spec:
#       containers:
#         - name: python
#           image: python:3.10
#           command:
#             - sleep       #
#             - infinity
#
#     """
#     }
#     }
#
#     environment {
#         VENV_DIR = 'venv'
#     }
#
#     stages {
#       stage('Run') {
#         steps {
#           sh 'python --version'
#         }
#       }
#
#      stage('Verify') {
#        steps {
#           sh 'ls-la'
#         }
#       }
#
#       stage('Setup python Environment') {
#         steps { // use . $VENV_DIR/bin/activate as source $VENV_DIR/bin/activate
#           sh '''
#           python3 -m venv $VENV_DIR
#           . $VENV_DIR/bin/activate
#
#           pip install -r requirements.txt
#           '''
#         }
#       }
#
#       stage('Run Tests') {
#         steps {
#           sh '''
#           . venv/bin/activate
#           which pytest
#           export PYTHONPATH=$(pwd)
#           pytest
#           '''
#         }
#       }
#
#     }
#   }
#  ```
# * for configuration of project in jenkins see below:
# * ![image.png](attachment:dcfc5b87-915d-4171-aea9-ed3e4b281861.png)
# * ![image.png](attachment:f4799f9d-8035-4469-a5f6-7d9c7f15f86b.png)

# %% [markdown]
# #### Set up pipeline by jenkinsfile in code repo using kubernetes agent with DVC functions
# * this is the full scale of jenkinsfile using k8s agent and integrate the dvc functions for dataset tracking
# * the idea is to use dvc to track dataset, save and upload the git and dvc hash/commit number of dataset update to MLFlow run associated with models and training
# * we can restore the training datasets from git and dvc hash/commit numbers from dvc
# * this avoids the redundant upload and store training datasets and dvc manages to only store the changes in dataset for data tracking
# * For details of setting dvc, see the corresponding notebook of MLOps_instruction
#   ```YAML
#   pipeline {
#     agent {
#   kubernetes {
#     namespace 'jenkins'
#         defaultContainer 'python'
#     yaml     """
# apiVersio    n: v1
# kin    d: Pod
# spec:
#   con    tainers:
#     - nam    e: python
#       image:  huangyuan2000/python-    dvc:3.10.1
#           command:
#             - sleep
#             - infini    ty
#       env:
#         - name: AW    S_ACCESS_KEY_ID
#               valueFrom:
#                 secretKeyRef:
#               name:     minio-credentials
#                   key: access_key
#         - name: A    WS_SECRET_ACCESS_KEY
#
#           valueFrom:
#                 secretKeyRef:
#                   name: minio-credentials
#                           key: secret_key
# """
#   }
# }
#
#     environment {
#             VENV_DIR = 'venv'
#         }
#
#
#     triggers {
#         pollSCM('H 5 * * *') // Polls daily at 5 AM
#     }
#
#     stages{
#         stage('Verify Python') {
#             steps {
#                 sh 'python3 --version'
#                 sh 'which python3'
#                 s     branch: 'master'
# //              }
# //          }
#
#         stage('Verify MinIO Credentials (Env)') {
#             steps {
#                 sh '''
#                     [ -n "$AWS_ACCESS_KEY_ID" ] || exit 1
#                     [ -n "$AWS_SECRET_ACCESS_KEY" ] || exit 1
#                     echo "MinIO credentials present"
#                 '''
#             }
#         }
#
#         stage('Verify MinIO Access (mc)') {
#             steps {
#                 sh '''
#                     mc alias set minio http://minio.mlops.svc.cluster.local:9000 \
#                         "$AWS_ACCESS_KEY_ID" "$AWS_SECRET_ACCESS_KEY"
#
#                     echo "MinIO buckets:"
#                             mc ls minio
#                         '''
#             }
#
#         }
#
#
#
# stage('Verify DVC Configuration')         {
#             steps {
#                         sh '''
#                             dvc --version
#                             dvc root
#                     dvc remote list
#                             dvc         remote default
#                             echo "DVC configuration val        id"
#                         '''
#                     }
#         }
#
# stage('Verify DVC Access to MinIO') {
#
#     steps {
#         sh '        ''
#             echo "Checking DVC ↔ MinIO         connectivity         (read        -only)"
#             dvc status -c
#             echo "DVC remote is reachable"
#         '''
#     }
# }
#         stage('Setup Python Environment') {
#             steps {
#                 sh '''
#
#                     python3 -m venv $VENV_DIR
#                     . $VENV_DIR/biactivate
#
#                    pip install -r requirements.txt
#                 '''
#             }
#         }
#
#
#
#         stage('Run Tests') {
#             steps {
#                 sh '''
#                     . venv/bin/activate
#                     which pytest
#
# ```               export PYTHONPATH=$(pwd)
#                     pytest
#                 '''
#             }
#         }
#
#
#     }
# }
